# %%
import scipy as sp

# %%
a=sp.array([[1,2],[0,1]])

# %%
a
# Out:
# array([[1, 2],
#        [0, 1]])

# %%
import scipy.constants as const

# %%
const.pi
# Out:
# 3.141592653589793

# %%
from scipy.interpolate import interp1d

# %%
import scipy.interpolate as interpolate

# %%
import scipy

# %%
x=scipy.linspace(0,2*scipy.pi,100)

# %%
xn=scipy.linspace(0,2*scipy.pi,10)

# %%
def func(x):
    return scipy.sin(x)

# %%
y=func(x)

# %%
yn=func(xn)

# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib inline
plt.plot(x,y)
plt.plot(xn,yn)

# %%
infunc = interp1d(xn,yn, kind='linear')
infunc1= interp1d(xn,yn, kind = 'quadratic')

# %%
# %matplotlib inline
plt.plot(x,y)
plt.scatter(xn,yn)
plt.plot(x,infunc(x), c='r')
plt.plot(x,infunc1(x), c='g')

# %%
from scipy.optimize import curve_fit
import scipy

# %%
def func(x,a,b):
    return a*x+b

# %%
x=scipy.linspace(0,10,100)

# %%
y=func(x,2,1)

# %%
yn=y+0.9*scipy.random.normal(size=len(x))

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.plot(x,y,c='r')
plt.scatter(x,yn,c='b',s=2)
plt.plot(x,func(x,*soln[0]),c='k')

# %%
soln =curve_fit(func,x,yn)

# %%
soln
# Out:
# (array([2.01439231, 0.87562088]), array([[ 0.00093633, -0.00468163],
#         [-0.00468163,  0.03136851]]))

# %%
scipy.sqrt(soln[1][0,0]) #ค่า error ตัวแรก
# Out:
# 0.030599449057446205

# %%
scipy.sqrt(soln[1][1,1]) #ค่า error ตัวสอง
# Out:
# 0.1771115622308636

# %% [markdown]
# Intigrate

# %%
from scipy.integrate import quad

# %%
func=lambda x : scipy.sin(x)

# %%
quad(func,0,scipy.pi)
# Out:
# (2.0, 2.220446049250313e-14)

# %%
quad(func,0,2*scipy.pi)
# Out:
# (2.221501482512777e-16, 4.3998892617845996e-14)

# %%
quad(lambda x : 2*scipy.exp(-x**2)/scipy.sqrt(scipy.pi),0,scipy.infty)
# Out:
# (1.0, 8.012979942038555e-09)

# %%
def func2(x,a,b):
     return a*x**2+b

# %%
quad(func2,0,1,args=(1,3)) #a=1, b=3
# Out:
# (3.3333333333333335, 3.700743415417189e-14)

# %%
from scipy.integrate import dblquad #integrate 2 ชั้น

# %%
dblquad(lambda y, x : x*y , 0, 1, 0, lambda x : x**2 ) #integrate by dy 0-x**2 and integrate by dx 0-1
# Out:
# (0.08333333333333334, 5.491107323698757e-15)

# %%
from scipy.integrate import tplquad #integrate 3 ชั้น

# %%
func2 = lambda x:x**2

# %%
func2(2)
# Out:
# 4
