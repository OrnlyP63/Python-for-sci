# %%
import pandas as pd

# %%
movie_df=pd.read_csv('MovieRating.csv')
movie_df
# Out:
#     Unnamed: 0                                             movie         year  \
# 0            0                                             Logan       (2017)
# 1            1                                    Thor: Ragnarok       (2017)
# 2            2                    Guardians of the Galaxy Vol. 2       (2017)
# 3            3                                      Wonder Woman       (2017)
# 4            4                                           Dunkirk       (2017)
# 5            5           Star Wars: Episode VIII - The Last Jedi       (2017)
# 6            6                            Spider-Man: Homecoming       (2017)
# 7            7                                           Get Out   (I) (2017)
# 8            8                                 Blade Runner 2049       (2017)
# 9            9                                       Baby Driver       (2017)
# 10          10                                                It   (I) (2017)
# ...

# %%
movie_df.head()
# Out:
#    Unnamed: 0                           movie    year  rating    vote
# 0           0                           Logan  (2017)     8.1  121002
# 1           1                  Thor: Ragnarok  (2017)     7.9  121002
# 2           2  Guardians of the Galaxy Vol. 2  (2017)     7.6  121002
# 3           3                    Wonder Woman  (2017)     7.4  121002
# 4           4                         Dunkirk  (2017)     7.9  121002

# %%
movie_df['movie']
# Out:
# 0                                                Logan
# 1                                       Thor: Ragnarok
# 2                       Guardians of the Galaxy Vol. 2
# 3                                         Wonder Woman
# 4                                              Dunkirk
# 5              Star Wars: Episode VIII - The Last Jedi
# 6                               Spider-Man: Homecoming
# 7                                              Get Out
# 8                                    Blade Runner 2049
# 9                                          Baby Driver
# 10                                                  It
# 11           Three Billboards Outside Ebbing, Missouri
# 12                                      Justice League
# 13                                  The Shape of Water
# 14                                John Wick: Chapter 2
# 15                                                Coco
# 16                      Jumanji: Welcome to the Jungle
# ...

# %%
movie_df[['movie','rating']]
# Out:
#                                                movie  rating
# 0                                              Logan     8.1
# 1                                     Thor: Ragnarok     7.9
# 2                     Guardians of the Galaxy Vol. 2     7.6
# 3                                       Wonder Woman     7.4
# 4                                            Dunkirk     7.9
# 5            Star Wars: Episode VIII - The Last Jedi     7.1
# 6                             Spider-Man: Homecoming     7.5
# 7                                            Get Out     7.7
# 8                                  Blade Runner 2049     8.0
# 9                                        Baby Driver     7.6
# 10                                                It     7.4
# 11         Three Billboards Outside Ebbing, Missouri     8.2
# 12                                    Justice League     6.4
# 13                                The Shape of Water     7.3
# ...

# %%
movie_df['movie'][1]
# Out:
# 'Thor: Ragnarok'

# %%
movie_df.loc[1]
# Out:
# Unnamed: 0                 1
# movie         Thor: Ragnarok
# year                  (2017)
# rating                   7.9
# vote                  121002
# Name: 1, dtype: object

# %%
movie_df.loc[[1,3]]
# Out:
#    Unnamed: 0           movie    year  rating    vote
# 1           1  Thor: Ragnarok  (2017)     7.9  121002
# 3           3    Wonder Woman  (2017)     7.4  121002

# %% [markdown]
# # การวิเคราะห์ข้อมูล

# %%
movie_df['rating'].unique() #ค่าไม่ซ้ำกัน
# Out:
# array([8.1, 7.9, 7.6, 7.4, 7.1, 7.5, 7.7, 8. , 8.2, 6.4, 7.3, 8.4, 6.9,
#        7.2, 6.6, 6.8, 6.7, 6.5, 5.5, 8.6, 8.7, 8.5, 5.2])

# %%
movie_df['rating'].nunique()#จำนวนไม่ซ้ำกัน
# Out:
# 23

# %%
movie_df['rating'].value_counts() #ข้อมูลที่ซ้ำกัน
# Out:
# 7.4    5
# 8.6    4
# 6.6    4
# 6.4    4
# 7.9    4
# 7.6    3
# 7.5    3
# 6.9    2
# 7.1    2
# 7.7    2
# 6.7    2
# 6.8    2
# 5.5    2
# 6.5    2
# 8.7    1
# 5.2    1
# 8.1    1
# 8.4    1
# 7.3    1
# 7.2    1
# 8.5    1
# 8.0    1
# 8.2    1
# Name: rating, dtype: int64

# %% [markdown]
# # selecting data

# %%
newdf=movie_df[movie_df['rating']>8]

# %%
newdf
# Out:
#     Unnamed: 0                                      movie         year  \
# 0            0                                      Logan       (2017)
# 11          11  Three Billboards Outside Ebbing, Missouri       (2017)
# 15          15                                       Coco   (I) (2017)
# 36          36                           La Casa de Papel     (2017– )
# 37          37                               The Punisher  (2017–2019)
# 44          44                                       Dark     (2017– )
# 45          45                                 Mindhunter     (2017– )
# 47          47                        The Handmaid's Tale     (2017– )
# 49          49                            Big Little Lies     (2017– )
#
#     rating    vote
# 0      8.1  121002
# 11     8.2  121002
# 15     8.4  121002
# 36     8.6  121002
# 37     8.6  121002
# 44     8.7  121002
# 45     8.6  121002
# 47     8.5  121002
# 49     8.6  121002

# %%
newdf=movie_df[(movie_df['rating']<8) & (movie_df['rating']>=7) ]

# %%
newdf
# Out:
#     Unnamed: 0                                    movie        year  rating  \
# 1            1                           Thor: Ragnarok      (2017)     7.9
# 2            2           Guardians of the Galaxy Vol. 2      (2017)     7.6
# 3            3                             Wonder Woman      (2017)     7.4
# 4            4                                  Dunkirk      (2017)     7.9
# 5            5  Star Wars: Episode VIII - The Last Jedi      (2017)     7.1
# 6            6                   Spider-Man: Homecoming      (2017)     7.5
# 7            7                                  Get Out  (I) (2017)     7.7
# 9            9                              Baby Driver      (2017)     7.6
# 10          10                                       It  (I) (2017)     7.4
# 13          13                       The Shape of Water      (2017)     7.3
# 14          14                     John Wick: Chapter 2      (2017)     7.5
# ...

# %%
movie_df.columns
# Out:
# Index(['Unnamed: 0', 'movie', 'year', 'rating', 'vote'], dtype='object')

# %% [markdown]
# # function

# %%
movie_df['vote'].sum()
# Out:
# 6050100

# %%
movie_df['rating'].mean()
# Out:
# 7.2860000000000005

# %%
movie_df.sort_values(by='rating')
# Out:
#     Unnamed: 0                                             movie         year  \
# 48          48                     Transformers: The Last Knight       (2017)
# 42          42                                          Baywatch       (2017)
# 35          35                                         The Mummy       (2017)
# 29          29                                Ghost in the Shell       (2017)
# 12          12                                    Justice League       (2017)
# 39          39                                            Bright   (I) (2017)
# 21          21                                   Alien: Covenant       (2017)
# 41          41       Valerian and the City of a Thousand Planets       (2017)
# 28          28                      Murder on the Orient Express       (2017)
# 33          33                                           Mother!       (2017)
# 25          25                                              Life   (I) (2017)
# ...

# %%
movie_df.sort_values(by='rating', ascending=False)
# Out:
#     Unnamed: 0                                             movie         year  \
# 44          44                                              Dark     (2017– )
# 49          49                                   Big Little Lies     (2017– )
# 45          45                                        Mindhunter     (2017– )
# 37          37                                      The Punisher  (2017–2019)
# 36          36                                  La Casa de Papel     (2017– )
# 47          47                               The Handmaid's Tale     (2017– )
# 15          15                                              Coco   (I) (2017)
# 11          11         Three Billboards Outside Ebbing, Missouri       (2017)
# 0            0                                             Logan       (2017)
# 8            8                                 Blade Runner 2049       (2017)
# 4            4                                           Dunkirk       (2017)
# ...

# %% [markdown]
# # Missing Data

# %%
df=pd.DataFrame({'A':[1,2,None],
                            'B':[5,None,None],
                            'C':[1,2,3]})

# %%
df
# Out:
#      A    B  C
# 0  1.0  5.0  1
# 1  2.0  NaN  2
# 2  NaN  NaN  3

# %%
df.dropna()
# Out:
#      A    B  C
# 0  1.0  5.0  1

# %%
df.dropna(axis=1)
# Out:
#    C
# 0  1
# 1  2
# 2  3

# %%
df.dropna(thresh=2)
# Out:
#      A    B  C
# 0  1.0  5.0  1
# 1  2.0  NaN  2

# %%
df.fillna(value='Fill')
# Out:
#       A     B  C
# 0     1     5  1
# 1     2  Fill  2
# 2  Fill  Fill  3

# %%
df['A']=df['A'].fillna(value=df['A'].mean())#เติมค่าเฉลี่ยนใน na

# %%
df
# Out:
#      A    B  C
# 0  1.0  5.0  1
# 1  2.0  NaN  2
# 2  1.5  NaN  3

# %% [markdown]
# # data visualization

# %%
movie_df.head()
# Out:
#    Unnamed: 0                           movie    year  rating    vote
# 0           0                           Logan  (2017)     8.1  121002
# 1           1                  Thor: Ragnarok  (2017)     7.9  121002
# 2           2  Guardians of the Galaxy Vol. 2  (2017)     7.6  121002
# 3           3                    Wonder Woman  (2017)     7.4  121002
# 4           4                         Dunkirk  (2017)     7.9  121002

# %%
movie_df['rating'].hist()

# %%
import matplotlib.pyplot as plt
plt.style.use('bmh') #เปลี่ยนธีมกราฟ

# %%
movie_df['rating'].hist()

# %%
plt.style.use('dark_background')
movie_df['rating'].hist()

# %%
plt.style.use('ggplot')
movie_df['rating'].hist()

# %%
df1=pd.read_csv('df1.csv')
df1.head()
# Out:
#           a         b         c         d
# 0  0.039762  0.218517  0.103423  0.957904
# 1  0.937288  0.041567  0.899125  0.977680
# 2  0.780504  0.008948  0.557808  0.797510
# 3  0.672717  0.247870  0.264071  0.444358
# 4  0.053829  0.520124  0.552264  0.190008

# %%
plt.style.use('ggplot')

# %% [markdown]
# # area

# %%
df1.plot.area(alpha=0.4)#ความโปร่งแสง

# %%
df1.plot.bar()

# %%
df1.plot.bar(stacked=True)

# %%
movie_df['rating'].plot.hist()

# %% [markdown]
# # line

# %%
df2=pd.read_csv('df2.csv')

# %%
df2.head()
# Out:
#          date         A         B         C         D
# 0  2000-01-01  1.339091 -0.163643 -0.646443  1.041233
# 1  2000-01-02 -0.774984  0.137034 -0.882716 -2.253382
# 2  2000-01-03 -0.921037 -0.482943 -0.417100  0.478638
# 3  2000-01-04 -1.738808 -0.072973  0.056517  0.015085
# 4  2000-01-05 -0.905980  1.778576  0.381918  0.291436

# %%
df2.plot.line(x='date',y='A',figsize=(12,3), lw=1)

# %% [markdown]
# # scatter plots

# %%
df2.plot.scatter(x='A',y='B')

# %%
df2.plot.scatter(x='A',y='B',c='C',cmap='coolwarm')

# %% [markdown]
# # Boxplots

# %%
df2.plot.box()
